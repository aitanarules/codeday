# %% [markdown]
# ### Librerías

# %%
# Librerías
import pandas as pd
import requests
import datetime

# !pip install geopandas
import geopandas as gpd
from difflib import SequenceMatcher # similitud de cadenas
import re                           # expresiones regulares
import chardet                      # codificación del fichero
from shapely.wkt import loads       # genera geometrías
# Out:
# C:\Users\34686\Downloads\Anaconda\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\34686\Downloads\Anaconda\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# C:\Users\34686\Downloads\Anaconda\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\34686\Downloads\Anaconda\lib\site-packages\geopandas\_compat.py:124: UserWarning: The Shapely GEOS version (3.11.2-CAPI-1.17.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# <ipython-input-1-f60070fc1914>:7: DeprecationWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas still uses PyGEOS by default. However, starting with version 0.14, the default will switch to Shapely. To force to use Shapely 2.0 now, you can either uninstall PyGEOS or set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In the next release, GeoPandas will switch to using Shapely by default, even if PyGEOS is installed. If you only have PyGEOS installed to get speed-ups, this switch should be smooth. However, if you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %% [markdown]
# <h1><center> Station </center></h1>

# %% [markdown]
# ### Lectura de datos

# %% [markdown]
# Links:
# * https://valencia.opendatasoft.com/explore/dataset/fgv-estacions-estaciones/export/
#
# * https://valencia.opendatasoft.com/explore/dataset/estacions-rodalia-valencia-val/export/
#
# * https://valencia.opendatasoft.com/explore/dataset/emt/table/
#
# * https://valencia.opendatasoft.com/explore/dataset/transporte-barrios/table/

# %%
# Nombre de los ficheros
metro = "Datos transporte/fgv-estacions-estaciones.geojson"
emt = "Datos transporte/transporte-barrios.geojson"
renfe = "Datos transporte/estacions-rodalia-valencia-val.geojson"
emt2 = "Datos transporte/emt.geojson"
emt3 = "Datos transporte/emt_concatenado_geometry.csv"

# Lectura de datos
gdf_met = gpd.read_file(metro)
gdf_emt = gpd.read_file(emt, encoding="utf-8")
gdf_ren = gpd.read_file(renfe)
gdf_emt2 = gpd.read_file(emt2)

# %% [markdown]
# ### Primera visualización

# %%
# Metrovalencia
gdf_met.head()
# Out:
#       gid codigo          nombre  tipo    linea  \
# 0  237118    110  Mas del Rosari     1        4
# 1  237200    183         La Cova     1        9
# 2  237215    121        Aeroport     1      3,5
# 3  237216      8       Almàssera     1        3
# 4  237142     15           Colón     1  3,5,7,9
#
#                                    proximas_llegadas  \
# 0  https://geoportal.valencia.es/geoportal-servic...
# 1  https://geoportal.valencia.es/geoportal-servic...
# 2  https://geoportal.valencia.es/geoportal-servic...
# 3  https://geoportal.valencia.es/geoportal-servic...
# 4  https://geoportal.valencia.es/geoportal-servic...
#
#                                    proximes_llegadas  \
# 0  https://geoportal.valencia.es/geoportal-servic...
# 1  https://geoportal.valencia.es/geoportal-servic...
# 2  https://geoportal.valencia.es/geoportal-servic...
# 3  https://geoportal.valencia.es/geoportal-servic...
# 4  https://geoportal.valencia.es/geoportal-servic...
#
#                                         geo_point_2d  \
# 0  {'lon': -0.43582499030541805, 'lat': 39.524959...
# 1  {'lon': -0.48444443970429724, 'lat': 39.498889...
# 2  {'lon': -0.47491943881419474, 'lat': 39.492366...
# 3  {'lon': -0.3542666730314796, 'lat': 39.5122566...
# 4  {'lon': -0.3709277814305924, 'lat': 39.4701462...
#
#                     geometry
# 0  POINT (-0.43582 39.52496)
# 1  POINT (-0.48444 39.49889)
# 2  POINT (-0.47492 39.49237)
# 3  POINT (-0.35427 39.51226)
# 4  POINT (-0.37093 39.47015)

# %%
# Emt
gdf_emt.head()
# Out:
#                                         geo_point_2d geo_shape codbarrio  \
# 0  {'lon': -0.38580384886348595, 'lat': 39.527643...      None         1
# 1  {'lon': -0.3993369274208722, 'lat': 39.4910315...      None         1
# 2  {'lon': -0.3872583065788684, 'lat': 39.4895628...      None         1
# 3  {'lon': -0.39681665593963605, 'lat': 39.494434...      None         1
# 4  {'lon': -0.3927782255244965, 'lat': 39.4960788...      None         1
#
#        nombre coddistbar coddistrit  codbar transporte  stop_id  \
# 0  BENIFARAIG        171         17     171        emt   1137.0
# 1   BENICALAP        161         16     161   metrovlc     54.0
# 2   BENICALAP        161         16     161   metrovlc     96.0
# 3   BENICALAP        161         16     161   metrovlc     99.0
# 4   BENICALAP        161         16     161        emt   1067.0
#
#                    stop_name                              stop_desc  \
# 0    Ferrer i Bign� - Aiacor       C FERRER Y BIGNE 21 - BENIFARAIG
# 1                  Beniferri                                   NULL
# 2                   Tr�nsits                                   NULL
# 3                   Florista                                   NULL
# 4  Equador - Pintor Matarana  AV ECUADOR  EL 93 (DAVANT) - VAL�NCIA
#
#            x           y zone_id                   geometry
# 0  724691.91  4378596.09    None  POINT (-0.38580 39.52764)
# 1  723646.02  4374498.31       A  POINT (-0.39934 39.49103)
# 2  724689.60  4374365.36       A  POINT (-0.38726 39.48956)
# 3  723851.86  4374882.28       A  POINT (-0.39682 39.49443)
# 4  724193.89  4375074.89    None  POINT (-0.39278 39.49608)

# %%
# Rodalies
gdf_ren.head()
# Out:
#                              geo_point_2d geo_shape   codi   descripci  \
# 0   {'lon': -0.320388, 'lat': 39.5441373}      None  65005   ALBUIXECH
# 1  {'lon': -0.0775039, 'lat': 39.9543523}      None  65209   ALMASSORA
# 2  {'lon': -0.2156704, 'lat': 39.7522591}      None  65202    ALMENARA
# 3  {'lon': -0.7875467, 'lat': 39.4273336}      None  66206       BUÑOL
# 4  {'lon': -0.4547076, 'lat': 39.1182487}      None  64103  CARCAIXENT
#
#       latitud    longitud                        direcci  \
# 0  39.5441373   -0.320388       AVENIDA VIRGEN ALBUIXECH
# 1  39.9543523  -0.0775039     CARRER ESTACIO FERROCARRIL
# 2  39.7522591  -0.2156704     CALLE ESTACION FERROCARRIL
# 3  39.4273336  -0.7875467     CALLE ESTACION FERROCARRIL
# 4  39.1182487  -0.4547076  GLORIETA ESTACION FERROCARRIL
#
#                     geometry
# 0  POINT (-0.32039 39.54414)
# 1  POINT (-0.07750 39.95435)
# 2  POINT (-0.21567 39.75226)
# 3  POINT (-0.78755 39.42733)
# 4  POINT (-0.45471 39.11825)

# %% [markdown]
# ### Modificación de atributos
# Para poder mergearlos posteriormente y tener solo uno con los siguientes atributos:
# * id
# * nombre
# * longitud
# * latitud
# * geometry
# * linea
# * tipo
# * municipio

# %%
# Metrovalencia

def coordenadas_long(x):
    return x['lon']
def coordenadas_lat(x):
    return x['lat']

# Obtener columnas
gdf_met['longitud'] = list(map(coordenadas_long, gdf_met.geo_point_2d))
gdf_met['latitud'] = list(map(coordenadas_lat, gdf_met.geo_point_2d))

# Eliminar columnas
columnas_eliminar = ['codigo', 'tipo', 'proximas_llegadas', 'proximes_llegadas', 'geo_point_2d']
gdf_met.drop(columnas_eliminar, axis=1, inplace=True)

# Renombrar columnas
gdf_met.rename(columns={'gid': 'id'}, inplace=True)

# Agregar columnas
gdf_met['tipo'] = 'metrovalencia'
gdf_met['municipio'] = None

gdf_met.head()
# Out:
#        id          nombre    linea                   geometry  longitud  \
# 0  237118  Mas del Rosari        4  POINT (-0.43582 39.52496) -0.435825
# 1  237200         La Cova        9  POINT (-0.48444 39.49889) -0.484444
# 2  237215        Aeroport      3,5  POINT (-0.47492 39.49237) -0.474919
# 3  237216       Almàssera        3  POINT (-0.35427 39.51226) -0.354267
# 4  237142           Colón  3,5,7,9  POINT (-0.37093 39.47015) -0.370928
#
#      latitud           tipo municipio
# 0  39.524960  metrovalencia      None
# 1  39.498890  metrovalencia      None
# 2  39.492367  metrovalencia      None
# 3  39.512257  metrovalencia      None
# 4  39.470146  metrovalencia      None

# %%
# Renfe

   
no = {"L", "LA", "EL", "DE", "DEL", "DELS", "I"}

def palabra_con_apostrof_guionet(palabra):
    list_pal = palabra.split("-")
    res = []
    for i, pal in enumerate(list_pal):
        apostrof = pal.find("'")
        if apostrof != -1:
            res.append(pal[0].upper()+pal[1]+pal[2:].capitalize())
        elif pal in no:
            res.append(pal.lower())
        else:
            res.append(pal.capitalize())
    palabra = "-".join(res)
    return palabra

def palabra_con_guionet(palabra):
    list_pal = palabra.split("-")
    list_pal = [pal.capitalize() for pal in list_pal]
    palabra = "-".join(list_pal)
    return palabra
   
    
def capitalizar(palabra):
    if palabra is None:
        return None
    
    list_pal = palabra.split()
    res = []
    for i, pal in enumerate(list_pal):
        apostrof = pal.find("'")
        guionet = pal.find("-")
                       
        if i==0 and pal in no:
            res.append(pal.capitalize())
        elif guionet!=-1 and apostrof!=-1:            
            res.append(palabra_con_apostrof_guionet(pal))
        elif apostrof!=-1:
            res.append(palabra[apostrof-1].upper()+palabra[apostrof]+palabra[apostrof+1:].capitalize())
        elif guionet!=-1:
            res.append(palabra_con_guionet(pal))
        elif pal in no:
            res.append(pal.lower())
        else:
            res.append(pal.capitalize())
    res = " ".join(res)
    return res
    

# Eliminar columnas
columnas_eliminar = ['geo_point_2d', 'geo_shape', 'direcci']
gdf_ren.drop(columnas_eliminar, axis=1, inplace=True)

# Renombrar columnas
gdf_ren.rename(columns={'codi': 'id'}, inplace=True)
gdf_ren.rename(columns={'descripci': 'municipio'}, inplace=True)

# Añadir columnas
gdf_ren['tipo'] = 'renfe'
gdf_ren['linea'] = None

# Modificar columnas
gdf_ren['municipio'] = list(map(capitalizar, gdf_ren.municipio))
gdf_ren['nombre'] = gdf_ren.municipio

gdf_ren.head()
# Out:
#       id   municipio     latitud    longitud                   geometry  \
# 0  65005   Albuixech  39.5441373   -0.320388  POINT (-0.32039 39.54414)
# 1  65209   Almassora  39.9543523  -0.0775039  POINT (-0.07750 39.95435)
# 2  65202    Almenara  39.7522591  -0.2156704  POINT (-0.21567 39.75226)
# 3  66206       Buñol  39.4273336  -0.7875467  POINT (-0.78755 39.42733)
# 4  64103  Carcaixent  39.1182487  -0.4547076  POINT (-0.45471 39.11825)
#
#     tipo linea      nombre
# 0  renfe  None   Albuixech
# 1  renfe  None   Almassora
# 2  renfe  None    Almenara
# 3  renfe  None       Buñol
# 4  renfe  None  Carcaixent

# %%
# Emt

def coordenadas_long(x):
    if x is not None:
        return x['lon']
def coordenadas_lat(x):
    if x is not None:
        return x['lat']

# Añadir columnas
gdf_emt['longitud'] = list(map(coordenadas_long, gdf_emt.geo_point_2d))
gdf_emt['latitud'] = list(map(coordenadas_lat, gdf_emt.geo_point_2d))
gdf_emt['linea'] = None

# Quitar filas
filas_eliminar = gdf_emt[gdf_emt['transporte']!='emt'].index
gdf_emt.drop(filas_eliminar, axis=0, inplace=True)

# Quitar columnas
columnas_eliminar = ['geo_point_2d', 'geo_shape', 'codbarrio', 'coddistbar', 'coddistrit', 'codbar', 'stop_desc', 'x', 'y', 'zone_id']
gdf_emt.drop(columnas_eliminar, axis=1, inplace=True)

# Renombrar columnas
gdf_emt.rename(columns={'stop_id': 'id'}, inplace=True)
gdf_emt.rename(columns={'stop_name': 'direccion'}, inplace=True)
gdf_emt.rename(columns={'transporte': 'tipo'}, inplace=True)
gdf_emt.rename(columns={'nombre': 'municipio'}, inplace=True)
gdf_emt.rename(columns={'direccion': 'nombre'}, inplace=True)

# Modificar columna
gdf_emt['municipio'] = list(map(capitalizar, gdf_emt.municipio))

gdf_emt.head()
# Out:
#     municipio tipo      id                                      nombre  \
# 0  Benifaraig  emt  1137.0                     Ferrer i Bign� - Aiacor
# 4   Benicalap  emt  1067.0                   Equador - Pintor Matarana
# 5   Benicalap  emt  1183.0  General Avil�s (par) - Dr. Nicasi Benlloch
# 6   Benicalap  emt  1319.0     Corts Valencianes - Palau de Congressos
# 7   Benicalap  emt  1331.0                      Florista - Carrasqueta
#
#                     geometry  longitud    latitud linea
# 0  POINT (-0.38580 39.52764) -0.385804  39.527644  None
# 4  POINT (-0.39278 39.49608) -0.392778  39.496079  None
# 5  POINT (-0.39146 39.48804) -0.391461  39.488037  None
# 6  POINT (-0.40182 39.49418) -0.401818  39.494184  None
# 7  POINT (-0.39621 39.49405) -0.396209  39.494049  None

# %%
# EMT 2

def coordenadas_long(x):
    if x is not None:
        return x['lon']
def coordenadas_lat(x):
    if x is not None:
        return x['lat']

# Añadir columnas
gdf_emt2['longitud'] = list(map(coordenadas_long, gdf_emt2.geo_point_2d))
gdf_emt2['latitud'] = list(map(coordenadas_lat, gdf_emt2.geo_point_2d))

# Quitar columnas
columnas_eliminar = ['codvia', 'numportal', 'suprimida', 'proximas_llegadas', 'geo_point_2d']
gdf_emt2.drop(columnas_eliminar, axis=1, inplace=True)

# Renombrar columnas
gdf_emt2.rename(columns={'id_parada': 'id'}, inplace=True)
gdf_emt2.rename(columns={'denominacion': 'nombre'}, inplace=True)
gdf_emt2.rename(columns={'lineas': 'linea'}, inplace=True)


gdf_emt2.head()
# Out:
#        id                                             nombre  \
# 0  2180.0                   Gavines (parell) - Platja (2180)
# 1  2240.0  Actor Antonio Ferrandis (imparell) - En Corts ...
# 2  2032.0                                   Les Corts (2032)
# 3  2194.0                          Gavines - Botavara (2194)
# 4  2193.0                         Gavines - Les dunes (2193)
#
#                   linea                   geometry  longitud    latitud
# 0                    25  POINT (-0.28923 39.29760) -0.289232  39.297596
# 1                    99  POINT (-0.36244 39.44855) -0.362439  39.448552
# 2  11,16,26,6,80,94,N10  POINT (-0.37427 39.47872) -0.374268  39.478722
# 3                    25  POINT (-0.29455 39.30528) -0.294552  39.305285
# 4                    25  POINT (-0.29169 39.30210) -0.291694  39.302102

# %% [markdown]
# ##### ¡menudo marrón!

# %%
# for i, row in gdf_emt.iterrows():
#     print(row.municipio,'>>', row.nombre)
    
# for i, row in enumerate(gdf_emt2['nombre']):
#     print(row, gdf_emt2['linea'][i])
    
# for x, y in zip(sorted(gdf_emt.intento1), sorted(gdf_emt2.intento1)):
#     print(x, "||", y)



with open(emt, 'rb') as f:
    resultado = chardet.detect(f.read())

# codificación detectada
print(resultado)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# Queremos concatenar los dos ficheros de EMT porque uno contiene las líneas mientras que otro contiene la ubicación. El problema está en el nombre de la parada, así como la longitud, porque no hemos encontrado el encoding que permita tomar los acentos en gdf_emt y la longitud de gdf_emt2 es menor que gdf_emt.
#
# En este apartado `¡menudo marrón!` hemos querido conservar las posibilidades que hemos considerado para concatenar
#
# Nota: esto no funciona, lo he intentado
#
#     >> pd.merge(gdf_emt, gdf_emt2, on=['longitud', 'latitud'], how='inner')
#     >> pd.merge(gdf_emt, gdf_emt2, on="geometry", how='inner')

# %%
def mis_palabras(palabra):
    """
    función que elimina los paréntesis y el contenido interno de los mismos. también se podría quitar el guión pero
    al final hemos decidirlo conservarlo
    """
    a = re.sub(r"\([^()]+\)", "", palabra) # | -
#     b = a.split()
#     c = set(b)
    return a.strip()

def similitud(x, y):
    """
    función que devuelve true en el caso que encuentre dos cadenas similares al 0.94%
    """
    
    s = SequenceMatcher(None, x, y).ratio()
    if s>0.94:
        return True
    else:
        return False
    return(s)

def similitud_1(x, y):
    """
    función que devuelve true en el caso que encuentre dos cadenas similares al 100%. es equivalente al ==
    """
    
    s = SequenceMatcher(None, x, y).ratio()
    if s==1:
        return True
    else:
        return False

# %%
# Reformateamos los nombres de las paradas de emt para quitar signos innecesarios

gdf_emt2["intento1"] = list(map(mis_palabras, gdf_emt2['nombre'])) 
gdf_emt["intento1"] = list(map(mis_palabras, gdf_emt['nombre']))

# %%
# Agregamos una columna con los índices

gdf_emt2["indices"] = [i for i in range(len(gdf_emt2))]
gdf_emt["indices"] = [i for i in range(len(gdf_emt))]

# %%
# Primera aproximación: calcular la similitud de las cadenas y crear un diccionario que asocie las más comunes

# true_pals_indice = {}
# for i, x in zip(gdf_emt.indices, gdf_emt.intento1):
#     true_pals_indice[i] = []
#     for j, y in zip(gdf_emt2.indices, gdf_emt2.intento1):
#         if similitud(x, y):
#             true_pals_indice[i].append(j)

# %%
# Segunda aproximación: equivalente a la primera pero agregando solo un índice

# for i, x in zip(gdf_emt.indices, gdf_emt.intento1):
#     true_pals_indice[i] = None
#     for j, y in zip(gdf_emt2.indices, gdf_emt2.intento1):
#         if similitud(x, y):
#             true_pals_indice[i] = j
#             gdf_emt2.at[j, "indices"] = i

# %%
# La forma de proceder en caso de la primera y segunda aproximación es la siguiente:

# # Lista para almacenar los GeoDataFrames concatenados
# concatenados = []

# # Recorres el diccionario
# for indice_gdf_emt, indices_gdf_emt2 in true_pals_indice.items():
#     # Seleccionas las filas que corresponden a los índices de cada GeoDataFrame
#     gdf_emt_seleccionado = gdf_emt[gdf_emt['indices'] == indice_gdf_emt]
#     gdf_emt2_seleccionado = gdf_emt2[gdf_emt2['indices'].isin(indices_gdf_emt2)]
#     # Concatenas los GeoDataFrames seleccionados
#     gdf_concatenado = gpd.GeoDataFrame(pd.concat([gdf_emt_seleccionado, gdf_emt2_seleccionado], axis=0))
#     # Agregas el GeoDataFrame concatenado a la lista
#     concatenados.append(gdf_concatenado)

# # Concatenas los GeoDataFrames de la lista
# resultado = pd.concat(concatenados, axis=0)

# print(resultado)

# %% [markdown]
# ¡Si quieres ejecutarlo todo, descomenta estas dos celdas de abajo!

# %%
# Tercera aproximación: comparamos directamente la columna de coordenadas. Por alguna razón le cuesta cargar

"""
for i, xrow in gdf_emt.iterrows():
    for j, yrow in gdf_emt2.iterrows():
        if str(xrow.geometry)== str(yrow.geometry):
            gdf_emt2.at[j, "indices"] = i
"""
# Out:
# '\nfor i, xrow in gdf_emt.iterrows():\n    for j, yrow in gdf_emt2.iterrows():\n        if str(xrow.geometry)== str(yrow.geometry):\n            gdf_emt2.at[j, "indices"] = i\n'

# %%
# Concatenamos los índices resultantes de ser idénticos
"""
df_concatenado_por_geometry = pd.merge(gdf_emt, gdf_emt2, on="indices", how='inner')
df_concatenado_por_geometry.to_csv("Datos transporte/emt_concatenado_geometry.csv", index=False) # exportar a geojson no va
"""
# Out:
# '\ndf_concatenado_por_geometry = pd.merge(gdf_emt, gdf_emt2, on="indices", how=\'inner\')\ndf_concatenado_por_geometry.to_csv("Datos transporte/emt_concatenado_geometry.csv", index=False) # exportar a geojson no va\n'

# %% [markdown]
# ----

# %% [markdown]
# ### Arreglar datos faltantes

# %%
# Nos aseguramos que todos tienen los mismos elementos (tiene que haber 8)

smet = set(gdf_met.columns)
semt = set(gdf_emt.columns)
sren = set(gdf_ren.columns)

smet&semt&sren
# Out:
# {'geometry',
#  'id',
#  'latitud',
#  'linea',
#  'longitud',
#  'municipio',
#  'nombre',
#  'tipo'}

# %%
# gdf_met.to_file('metrovalencia.geojson', driver='GeoJSON')  
# gdf_emt.to_file('emt.geojson', driver='GeoJSON')  
# gdf_ren.to_file('renfe.geojson', driver='GeoJSON')

# %%
# METROVALENCIA

# Falta municipio
gdf_met.head()

# for i, m in enumerate(gdf_met['nombre']):
#     print(i+1, m)
    
municipios_met = {}

def anyadir_municipio(estacion, municipio, dic=municipios_met, estaciones = set(gdf_met['nombre'])):
    if estacion in dic:
        print('YA EXISTE', estacion)
    elif estacion not in estaciones :
        print('NO EXISTE', estacion)
    else:
        dic[estacion] = municipio

# %%
## https://www.metrovalencia.es/es/consulta-estaciones/

anyadir_municipio('Mas del Rosari', 'La Coma - València')
anyadir_municipio('La Cova', 'Manises')
anyadir_municipio('Aeroport', 'Manises')
anyadir_municipio('Almàssera', 'Almàssera')
anyadir_municipio('Colón', 'Sant Francesc - València')
anyadir_municipio('Ayora', 'Aiora - València')
anyadir_municipio('Bétera', 'Bétera')
anyadir_municipio('Torrent Avinguda', 'Torrent')
anyadir_municipio('Alberic', 'Alberic')
anyadir_municipio('Carlet', 'Carlet')
anyadir_municipio('Col·legi El Vedat', 'Torrent')
anyadir_municipio('Moreres', 'Moreres - València')
anyadir_municipio('Sant Isidre', 'Sant Isidre - València')
anyadir_municipio('Sant Miquel dels Reis', 'Els Orriols - València')
anyadir_municipio('La Presa', 'Manises')
anyadir_municipio('Masia de Traver', 'Riba-roja de Túria')
anyadir_municipio('Jesús', 'La Raiosa - València')
anyadir_municipio('Patraix', 'Patraix - València')
anyadir_municipio('Omet', 'Picassent')
anyadir_municipio('Paiporta', 'Paiporta')
anyadir_municipio('Burjassot - Godella', 'Burjassot')
anyadir_municipio('Godella', 'Godella')
anyadir_municipio('Horta Vella', 'Bétera')
anyadir_municipio('Alfauir', 'Sant Llorenç - València')
anyadir_municipio('Parc Científic', 'Paterna')
anyadir_municipio('Tomás y Valiente', 'Paterna')
anyadir_municipio('Francesc Cubells', 'Grao - València')
anyadir_municipio('Grau - La Marina', 'Grao - València')
anyadir_municipio('Tossal del Rei', 'Torrefiel - València')
anyadir_municipio('Av. del Cid', 'València')
anyadir_municipio('Llíria', 'Llíria')
anyadir_municipio('Àngel Guimerà', 'Arrancapins - València')
anyadir_municipio('Campament', 'Paterna')
anyadir_municipio('Picanya', 'Picanya')
anyadir_municipio('Albalat dels Sorells', 'Albalat dels Sorells')
anyadir_municipio('Reus', 'Marxalenes - València')
anyadir_municipio('Trànsits', 'Benicalap - València')
anyadir_municipio('Benicalap', 'Benicalap - València')
anyadir_municipio('La Carrasca', 'La Carrasca - València')
anyadir_municipio('Dr. Lluch', 'Cabanyal-Canyamelar - València')
anyadir_municipio('Universitat Politècnica', 'La Carrasca - València')
anyadir_municipio('Alboraia Peris Aragó', 'Alboraia')
anyadir_municipio('Fondo de Benaguasil', 'Benaguasil')
anyadir_municipio('Gallipont - Torre del Virrei', 'L\'Eliana')
anyadir_municipio('Fuente del Jarro', 'Paterna')
anyadir_municipio('L\'Alcúdia', 'L\'Alcúdia')
anyadir_municipio('Sant Ramon', 'Picassent')
anyadir_municipio('Garbí', 'Benicalap - València')
anyadir_municipio('Florista', 'Benicalap - València')
anyadir_municipio('Neptú', 'Grao - València')
anyadir_municipio('Machado', 'Benimaclet - València')
anyadir_municipio('Roses', 'Manises')
anyadir_municipio('Amistat', 'Amistat - València')
anyadir_municipio('Aragó', 'Mestalla - València')
anyadir_municipio('Castelló', 'Castelló de la Ribera')
anyadir_municipio('Alginet', 'Alginet')
anyadir_municipio('Quatre Carreres', 'La Fonteta de Sant Lluís - València')
anyadir_municipio('Oceanogràfic', 'Ciutat de les Arts i les Ciències - València')
anyadir_municipio('Palau de Congressos', 'Benicalap - València')
anyadir_municipio('Campus', 'Burjassot')
anyadir_municipio('Entrepins', 'L\'Eliana')
anyadir_municipio('Burjassot', 'Burjassot')
anyadir_municipio('Mislata', 'Mislata')
anyadir_municipio('Túria', 'Campanar - València')
anyadir_municipio('La Vallesa', 'Paterna')
anyadir_municipio('Montortal', 'L\'Alcúdia')
anyadir_municipio('Rocafort', 'Rocafort')
anyadir_municipio('Moncada - Alfara', 'Moncada')
anyadir_municipio('Masies', 'Moncada')
anyadir_municipio('Russafa', 'Russafa - València')
anyadir_municipio('Orriols', 'Els Orriols - València')
anyadir_municipio('Pont de Fusta', 'Morvedre - València')
anyadir_municipio('Vicent Andrés Estellés', 'Burjassot')
anyadir_municipio('À Punt', 'Burjassot')
anyadir_municipio('La Coma', 'Paterna')
anyadir_municipio('Estadi Ciutat de València', 'Orriols - València')
anyadir_municipio('Xàtiva', 'Sant Francesc - València')
anyadir_municipio('Quart de Poblet', 'Quart de Poblet')
anyadir_municipio('Meliana', 'Meliana')
anyadir_municipio('Foios', 'Foios')
anyadir_municipio('Les Carolines - Fira', 'Benimàmet - València')
anyadir_municipio('Canyamelar', 'Cabanyal-Canyamelar - València')
anyadir_municipio('Font Almaguer', 'Benifaió')
anyadir_municipio('Sagunt', 'València')
anyadir_municipio('Campanar', 'Campanar - València')
anyadir_municipio('Massamagrell', 'Massamagrell')
anyadir_municipio('Massarrojos', 'Massarrojos')
anyadir_municipio('La Pobla de Farnals', 'La Pobla de Farnals')
anyadir_municipio('Facultats - Manuel Broseta', 'Exposició - València')
anyadir_municipio('El Clot', 'L\'Eliana')
anyadir_municipio('Safranar', 'Patraix - València')
anyadir_municipio('Ll. Llarga - Terramelar', 'Paterna')
anyadir_municipio('Salt de l\'Aigua', 'Manises')
anyadir_municipio('Bailén', 'La Roqueta - València')
anyadir_municipio('Rafelbunyol', 'Rafelbunyol')
anyadir_municipio('Alacant', 'Russafa - València')
anyadir_municipio('Faitanar', 'Quart de Poblet')
anyadir_municipio('L\'Eliana', 'L\'Eliana')
anyadir_municipio('Riba-roja de Túria', 'Riba-roja de Túria')
anyadir_municipio('Montesol', 'L\'Eliana')
anyadir_municipio('Picassent', 'Picassent')
anyadir_municipio('Torrent', 'Torrent')
anyadir_municipio('Ciutat Arts i Ciències - Justícia', 'Ciutat de les Arts i les Ciències - València')
anyadir_municipio('Natzaret', 'Natzaret - València')
anyadir_municipio('La Granja', 'Burjassot')
anyadir_municipio('Sant Joan', 'Burjassot')
anyadir_municipio('Museros', 'Museros')
anyadir_municipio('Alboraia Palmaret', 'Alboraia')
anyadir_municipio('València la Vella', 'Riba-roja de Túria')
anyadir_municipio('València Sud', 'Faitanar - València')
anyadir_municipio('Beniferri', 'Benicalap - València')
anyadir_municipio('Pl. Espanya', 'La Roqueta - València')
anyadir_municipio('Benimodo', 'Benimodo')
anyadir_municipio('Ausiàs March', 'Carlet')
anyadir_municipio('Espioca', 'Picassent')
anyadir_municipio('Seminari - CEU', 'Moncada')
anyadir_municipio('Amado Granell - Montolivet', 'Montolivet - València')
anyadir_municipio('Tarongers - Ernest Lluch', 'La Carrasca - València')
anyadir_municipio('Mislata Almassil', 'Mislata')
anyadir_municipio('Cabanyal', 'Cabanyal - València')
anyadir_municipio('Nou d\'Octubre', 'Soternes - València')
anyadir_municipio('Alameda', 'La Xerea - València')
anyadir_municipio('Manises', 'Manises')
anyadir_municipio('Paterna', 'Paterna')
anyadir_municipio('Marítim', 'Aiora - València')
anyadir_municipio('Benimàmet', 'Benimàmet - València')
anyadir_municipio('Cantereria', 'Burjassot')
anyadir_municipio('Benaguasil', 'Benaguasil')
anyadir_municipio('Realón', 'Picassent')
anyadir_municipio('Beteró', 'La Carrasca - València')
anyadir_municipio('Marxalenes', 'Marxalenes - València')
anyadir_municipio('Vicente Zaragozá', 'Ciutat Universitària - València')
anyadir_municipio('Trinitat', 'Benimaclet - València')
anyadir_municipio('La Pobla de Vallbona', 'La Pobla de Vallbona')
anyadir_municipio('Benimaclet', 'Benimaclet - València')
anyadir_municipio('La Canyada', 'Paterna')
anyadir_municipio('Santa Rita', 'Paterna')
anyadir_municipio('Massalavés', 'Massalavés')
anyadir_municipio('Empalme', 'Burjassot')
anyadir_municipio('La Cadena', 'Cabanyal-Canyamelar - València')
anyadir_municipio('Platja Malva-rosa', 'Cabanyal-Canyamelar - València')
anyadir_municipio('Platja les Arenes', 'Cabanyal-Canyamelar - València')

# %%
# Añadimos los cambios y fusionamos

df = pd.DataFrame([[key, municipios_met[key]] for key in municipios_met.keys()], columns=['nombre', 'municipio'])
gdf_met = gdf_met.merge(df, on="nombre")
del gdf_met['municipio_x']
gdf_met.rename(columns={'municipio_y': 'municipio'}, inplace=True)
gdf_met.head()
# Out:
#        id          nombre    linea                   geometry  longitud  \
# 0  237118  Mas del Rosari        4  POINT (-0.43582 39.52496) -0.435825
# 1  237200         La Cova        9  POINT (-0.48444 39.49889) -0.484444
# 2  237215        Aeroport      3,5  POINT (-0.47492 39.49237) -0.474919
# 3  237216       Almàssera        3  POINT (-0.35427 39.51226) -0.354267
# 4  237142           Colón  3,5,7,9  POINT (-0.37093 39.47015) -0.370928
#
#      latitud           tipo                 municipio
# 0  39.524960  metrovalencia        La Coma - València
# 1  39.498890  metrovalencia                   Manises
# 2  39.492367  metrovalencia                   Manises
# 3  39.512257  metrovalencia                 Almàssera
# 4  39.470146  metrovalencia  Sant Francesc - València

# %%
# EMT
gdf_emt.head()

# Falta línea
# for i, n in enumerate(gdf_emt['nombre']):
#     print(i, n)
    
    
# Falta arreglar municipio
# for i, n in enumerate(gdf_emt['municipio']):
#     print(i, n)

# Véase ¡menudo marrón!  --> obtenemos el siguiente fichero
gdf_emt3 = pd.read_csv(emt3)
gdf_emt3.head()
# Out:
#    municipio tipo    id_x                                    nombre_x  \
# 0  Benicalap  emt  1067.0                   Equador - Pintor Matarana
# 1  Benicalap  emt  1183.0  General Avil�s (par) - Dr. Nicasi Benlloch
# 2  Benicalap  emt  1183.0  General Avil�s (par) - Dr. Nicasi Benlloch
# 3  Benicalap  emt  1319.0     Corts Valencianes - Palau de Congressos
# 4  Benicalap  emt  1331.0                      Florista - Carrasqueta
#
#                                       geometry_x  longitud_x  latitud_x  \
# 0   POINT (-0.392778225524496 39.49607883121975)   -0.392778  39.496079
# 1   POINT (-0.391460962857036 39.48803711704195)   -0.391461  39.488037
# 2   POINT (-0.391460962857036 39.48803711704195)   -0.391461  39.488037
# 3  POINT (-0.401818139798389 39.494183715692415)   -0.401818  39.494184
# 4  POINT (-0.396208839095057 39.494049233440656)   -0.396209  39.494049
#
#    linea_x                               intento1_x  indices    id_y  \
# 0      NaN                Equador - Pintor Matarana        1  1067.0
# 1      NaN    General Avil�s  - Dr. Nicasi Benlloch        2  2032.0
# 2      NaN    General Avil�s  - Dr. Nicasi Benlloch        2  1183.0
# 3      NaN  Corts Valencianes - Palau de Congressos        3  1319.0
# 4      NaN                   Florista - Carrasqueta        4  1331.0
#
#                                          nombre_y               linea_y  \
# 0                Equador - Pintor Matarana (1067)                    12
# 1                                Les Corts (2032)  11,16,26,6,80,94,N10
# 2     General Avilés - Dr. Nicasi Benlloch (1183)                 64,94
# 3  Corts Valencianes - Palau de Congressos (1319)           62,63,99,N3
# 4                   Florista - Carrasqueta (1331)                    28
#
#                                        geometry_y  longitud_y  latitud_y  \
# 0   POINT (-0.3927782320996148 39.49607896649905)   -0.392778  39.496079
# 1   POINT (-0.3742677624589383 39.47872157854415)   -0.374268  39.478722
# 2  POINT (-0.3914609581496043 39.488037243059374)   -0.391461  39.488037
# 3   POINT (-0.401818111537627 39.494183850192464)   -0.401818  39.494184
# 4   POINT (-0.3962088210973265 39.49404940420439)   -0.396209  39.494049
#
#                                  intento1_y
# 0                Equador - Pintor Matarana
# 1                                Les Corts
# 2     General Avilés - Dr. Nicasi Benlloch
# 3  Corts Valencianes - Palau de Congressos
# 4                   Florista - Carrasqueta

# %%
# Quitar columnas
columnas_eliminar = ['id_x', 'nombre_x', 'geometry_x', 'longitud_x', 'latitud_x', 'linea_x', 'intento1_x', 'intento1_y', 'indices']
gdf_emt3.drop(columnas_eliminar, axis=1, inplace=True)

# Renombrar columnas
gdf_emt3.rename(columns={'id_y': 'id'}, inplace=True)
gdf_emt3.rename(columns={'nombre_y': 'nombre'}, inplace=True)
gdf_emt3.rename(columns={'linea_y': 'linea'}, inplace=True)
gdf_emt3.rename(columns={'longitud_y': 'longitud'}, inplace=True)
gdf_emt3.rename(columns={'latitud_y': 'latitud'}, inplace=True)
gdf_emt3.rename(columns={'geometry_y': 'geometry'}, inplace=True)

# Modificar columna
gdf_emt3['geometry'] = gdf_emt3['geometry'].apply(loads) # Convierte las cadenas de texto en objetos geométricos
gdf_emt3 = gpd.GeoDataFrame(gdf_emt3, geometry='geometry') # Crea un GeoDataFrame a partir del DataFrame df
gdf_emt3['nombre'] = list(map(mis_palabras, gdf_emt3.nombre))

gdf_emt3.head()
# Out:
#    municipio tipo      id                                   nombre  \
# 0  Benicalap  emt  1067.0                Equador - Pintor Matarana
# 1  Benicalap  emt  2032.0                                Les Corts
# 2  Benicalap  emt  1183.0     General Avilés - Dr. Nicasi Benlloch
# 3  Benicalap  emt  1319.0  Corts Valencianes - Palau de Congressos
# 4  Benicalap  emt  1331.0                   Florista - Carrasqueta
#
#                   linea                   geometry  longitud    latitud
# 0                    12  POINT (-0.39278 39.49608) -0.392778  39.496079
# 1  11,16,26,6,80,94,N10  POINT (-0.37427 39.47872) -0.374268  39.478722
# 2                 64,94  POINT (-0.39146 39.48804) -0.391461  39.488037
# 3           62,63,99,N3  POINT (-0.40182 39.49418) -0.401818  39.494184
# 4                    28  POINT (-0.39621 39.49405) -0.396209  39.494049

# %%
# RENFE
gdf_ren.head()
   
# Faltan estaciones? Viendo el mapa, no: quitamos los None
tiene_none = []
for i, n in enumerate(gdf_ren['nombre']):
    if n is None:
        tiene_none.append(i)
gdf_ren.drop(tiene_none, axis=0, inplace=True)


# Falta linea


# for i, n in enumerate(gdf_ren['municipio']):
#     print(i, n, n is None)

# gdf['nombre'] = gdf['municipio'].where(gdf['nombre'].isna(), gdf['nombre'])

c1 = ['Cullera', 'Valencia-Estacio del Nord', 'Xeraco', 'Alfafar-Benetusser', 'Catarroja', 'El Romaní', 'Gandia', 'Platja i Grau de Gandia', 'Silla', 'Sueca', 'Tavernes de la Valldigna', 'Massanassa', 'Sollana']
c2 = ['Moixent', 'Vallada', 'Montesa', "L'Alcúdia", 'Xàtiva', "L'Enova-Manuel", 'La Pobla Llarga', 'Carcaixent', 'Alzira', 'Algemesi', 'Benifaio', 'Valencia-Estacio del Nord', 'Alfafar-Benetusser', 'Catarroja', 'Silla', 'Massanassa']
c3 = ['Valencia Sant Isidre', 'Xirivella-Alqueries', 'Aldaia', 'Loriguilla-Reva', 'Circuit Ricardo Tormo', 'Cheste', 'Chiva', 'Buñol', 'Venta Mina-Siete Aguas', 'Siete Aguas', 'El Rebollar', 'Requena', 'San Antonio de Requena', 'Utiel']
c4 = ["Xirivella-L'Alter", 'Valencia Sant Isidre']
c5 = ['Valencia-La Font de Sant Lluís', 'Valencia-Cabanyal', 'Roca-Cuper', 'Albuixech', 'Massalfassar', 'El puig', 'Puçol', 'Sagunt', 'Les Valls', 'Almenara', 'La Llosa', 'Chilches', 'Moncofar', 'Nules-villavieja', 'Burriana-Alquerias del Niño Perdido', 'Vila-Real', 'Almassora', 'Castello de la Plana']
c6 = ['Valencia-La Font de Sant Lluís', 'Valencia-Cabanyal', 'Roca-Cuper', 'Albuixech', 'Massalfassar', 'El puig', 'Puçol', 'Sagunt', 'Algimia-Ciudad', 'Caudiel', 'Estivella-Albalat dels Tarongers', 'Gilet', 'Jerica-Viver', 'Navajas', 'Segorbe-Arrabal', 'Segorbe-Ciudad', 'Soneja']

for i, row in gdf_ren.iterrows():
    lineas = []
    if row.nombre in c1:
        lineas.append('C1')
    if row.nombre in c2:
        lineas.append('C2')
    if row.nombre in c3:
        lineas.append('C3')
    if row.nombre in c4:
        lineas.append('C4')
    if row.nombre in c5:
        lineas.append('C5')
    if row.nombre in c6:
        lineas.append('C6')
    lineas = ','.join(lineas)
    gdf_ren.at[i, 'linea'] = lineas

    
gdf_ren.head()
# Out:
#       id   municipio     latitud    longitud                   geometry  \
# 0  65005   Albuixech  39.5441373   -0.320388  POINT (-0.32039 39.54414)
# 1  65209   Almassora  39.9543523  -0.0775039  POINT (-0.07750 39.95435)
# 2  65202    Almenara  39.7522591  -0.2156704  POINT (-0.21567 39.75226)
# 3  66206       Buñol  39.4273336  -0.7875467  POINT (-0.78755 39.42733)
# 4  64103  Carcaixent  39.1182487  -0.4547076  POINT (-0.45471 39.11825)
#
#     tipo  linea      nombre
# 0  renfe  C5,C6   Albuixech
# 1  renfe     C5   Almassora
# 2  renfe     C5    Almenara
# 3  renfe     C3       Buñol
# 4  renfe     C2  Carcaixent

# %%
# Comprobación
# for i, n in enumerate(gdf_ren['municipio']):
#     print(i, n, gdf_ren["linea"][i])

# %% [markdown]
# ### Arreglar municipio y barrios

# %% [markdown]
# Existen algunas diferencias entre cómo llama EMT a los barrios y cómo los he nombrado yo, por ejemplo:
# * La Fonteta de Sant Lluís <=>  Fontsana
# * Ciutat de les Arts i les Ciències  <=>   La Ciutat de Les Arts i de Les Ciencies
# * Orriols  <=>  Els Orriols

# %%
# set(gdf_emt3.municipio)

# %%
# set(gdf_met.municipio)

# %%
dic_correccion_barrios = {'Benimamet': 'Benimàmet', 'Betero': 'Beteró',
                 'Borboto': 'Borbotó', 'Cami Fondo': 'Camí Fondo',
                 'Cami Real': 'Camí Real', 'Ciutat Jardi': 'Ciutat Jardí',
                 'Ciutat Universitaria': 'Ciutat Universitària',
                 'Ciutat de Les Arts i de Les Ciencies': 'Ciutat de les Arts i les Ciències',
                 'El Botanic':'El Botànic', "El Forn EL forn d'alcedo":"El Forn d'Alcedo",
                 'Exposicio': 'Exposició', "L'Hort de senabre de Senabre": "L'Hort de Senabre",
                 "L'Illa perduda Perduda": "L'Illa Perduda",
                 'La Fonteta S.lluis': 'La Fonteta de Sant Lluís',
                  'Mont-Olivet': 'Montolivet', 'Sant Llorens': 'Sant Llorenç',
                  'Sant Marcel.li':'Sant Marcel·lí'}

def corregir_barrios(barrio):
    if barrio in dic_correccion_barrios:
        return dic_correccion_barrios[barrio]+' - València'
    return barrio+' - València'
gdf_emt3["municipio"] = list(map(corregir_barrios,gdf_emt3.municipio))

# %%
dic_correcion_municipio = {'Alfafar-Benetusser':'Benetússer', 'Algemesi': 'Algemesí',
                          'Algimia-Ciudad': "Algímia d'Alfara", 'Benifaio': 'Benifaió',
                          'Burriana-Alquerias del Niño Perdido':'Les Alqueries',
                          'Buñol': 'Bunyol', 'Castello de la Plana': 'Castelló de la Plana' ,
                           'Cheste': 'Xest', 'Chilches': 'Xilxes',
                          'Chiva': 'Xiva', 'Circuit Ricardo Tormo': 'Xest',
                           'El Romani': 'Sollana', 
                           "Estivella-Albalat dels Tarongers": 'Estivella',
                           "Jerica-Viver":'Xèrica', "L'Alcudia":"L'Alcúdia",
                           "L'Enova-Manuel": "L'Énova", 'Les Valls': 'Sagunt',
                           'Loriguilla-Reva': 'Loriguilla', 'Moncofar':'Moncofa',
                           'Nules-Villavieja': 'Nules',
                           "Platja i Grau de Gandia": 'Gandia', 'El Rebollar': 'Requena',
                           'Roca-Cuper': 'Meliana',
                           'San Antonio de Requena': 'Requena', 'Segorbe-Arrabal': 'Segorbe',
                           'Segorbe-Ciudad': 'Segorbe', 'Siete Aguas':'Setaigües',
                           'Valencia Sant Isidre': 'Sant Isidre - València', 
                           'Valencia-Cabanyal': 'Cabanyal - València',
                           'Valencia-Estacio del Nord': 'Ciutat Vella - València',
                           'Valencia-La Font de Sant Lluis': 'La Fonteta de Sant Lluís - València',
                           'Venta Mina-Siete Aguas': 'Bunyol', 'Xativa':'Xàtiva',
                           'Xirivella-Alqueries': 'Xirivella', "Xirivella-L'Alter": 'Xirivella',
                           'Vila-Real': 'Vila-real'}

def corregir_municipio(municipio):
    if municipio in dic_correcion_municipio:
        return dic_correcion_municipio[municipio]
    return municipio
gdf_ren["municipio"] = list(map(corregir_municipio,gdf_ren.municipio))

# %% [markdown]
# ### Fusión

# %%
import geopandas as gpd

# Restablecer los índices de los GeoDataFrames para evitar índices duplicados
gdf_met.reset_index(drop=True, inplace=True)
gdf_emt3.reset_index(drop=True, inplace=True)
gdf_ren.reset_index(drop=True, inplace=True)

# %%
gdf = pd.concat([gdf_met,gdf_emt3, gdf_ren])
gdf.head()
# Out:
# C:\Users\34686\Downloads\Anaconda\lib\site-packages\geopandas\array.py:1486: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as WGS 84 (the single non-null crs provided).
#   warnings.warn(
#        id          nombre    linea                   geometry  longitud  \
# 0  237118  Mas del Rosari        4  POINT (-0.43582 39.52496) -0.435825
# 1  237200         La Cova        9  POINT (-0.48444 39.49889) -0.484444
# 2  237215        Aeroport      3,5  POINT (-0.47492 39.49237) -0.474919
# 3  237216       Almàssera        3  POINT (-0.35427 39.51226) -0.354267
# 4  237142           Colón  3,5,7,9  POINT (-0.37093 39.47015) -0.370928
#
#      latitud           tipo                 municipio
# 0   39.52496  metrovalencia        La Coma - València
# 1   39.49889  metrovalencia                   Manises
# 2  39.492367  metrovalencia                   Manises
# 3  39.512257  metrovalencia                 Almàssera
# 4  39.470146  metrovalencia  Sant Francesc - València

# %%
for i, row in gdf.iterrows():
    print(f'{i} {row.nombre} << {row.municipio}')
# Out:
# 0 Mas del Rosari << La Coma - València
# 1 La Cova << Manises
# 2 Aeroport << Manises
# 3 Almàssera << Almàssera
# 4 Colón << Sant Francesc - València
# 5 Ayora << Aiora - València
# 6 Bétera << Bétera
# 7 Torrent Avinguda << Torrent
# 8 Alberic << Alberic
# 9 Carlet << Carlet
# 10 Col·legi El Vedat << Torrent
# 11 Moreres << Moreres - València
# 12 Sant Isidre << Sant Isidre - València
# 13 Sant Miquel dels Reis << Els Orriols - València
# 14 La Presa << Manises
# 15 Masia de Traver << Riba-roja de Túria
# 16 Jesús << La Raiosa - València
# 17 Patraix << Patraix - València
# 18 Omet << Picassent
# 19 Paiporta << Paiporta
# 20 Burjassot - Godella << Burjassot
# 21 Godella << Godella
# 22 Horta Vella << Bétera
# 23 Alfauir << Sant Llorenç - València
# 24 Parc Científic << Paterna
# 25 Tomás y Valiente << Paterna
# 26 Francesc Cubells << Grao - València
# 27 Grau - La Marina << Grao - València
# 28 Tossal del Rei << Torrefiel - València
# 29 Av. del Cid << València
# 30 Llíria << Llíria
# 31 Àngel Guimerà << Arrancapins - València
# 32 Campament << Paterna
# 33 Picanya << Picanya
# 34 Albalat dels Sorells << Albalat dels Sorells
# 35 Reus << Marxalenes - València
# 36 Trànsits << Benicalap - València
# 37 Benicalap << Benicalap - València
# 38 La Carrasca << La Carrasca - València
# 39 Dr. Lluch << Cabanyal-Canyamelar - València
# 40 Universitat Politècnica << La Carrasca - València
# 41 Alboraia Peris Aragó << Alboraia
# 42 Fondo de Benaguasil << Benaguasil
# 43 Gallipont - Torre del Virrei << L'Eliana
# 44 Fuente del Jarro << Paterna
# 45 L'Alcúdia << L'Alcúdia
# 46 Sant Ramon << Picassent
# 47 Garbí << Benicalap - València
# 48 Florista << Benicalap - València
# 49 Neptú << Grao - València
# 50 Machado << Benimaclet - València
# 51 Roses << Manises
# 52 Amistat << Amistat - València
# 53 Aragó << Mestalla - València
# 54 Castelló << Castelló de la Ribera
# 55 Alginet << Alginet
# 56 Quatre Carreres << La Fonteta de Sant Lluís - València
# 57 Oceanogràfic << Ciutat de les Arts i les Ciències - València
# 58 Palau de Congressos << Benicalap - València
# 59 Campus << Burjassot
# 60 Entrepins << L'Eliana
# 61 Burjassot << Burjassot
# 62 Mislata << Mislata
# 63 Túria << Campanar - València
# 64 La Vallesa << Paterna
# 65 Montortal << L'Alcúdia
# 66 Rocafort << Rocafort
# 67 Moncada - Alfara << Moncada
# 68 Masies << Moncada
# 69 Russafa << Russafa - València
# 70 Orriols << Els Orriols - València
# 71 Pont de Fusta << Morvedre - València
# 72 Vicent Andrés Estellés << Burjassot
# 73 À Punt << Burjassot
# 74 La Coma << Paterna
# 75 Estadi Ciutat de València << Orriols - València
# 76 Xàtiva << Sant Francesc - València
# 77 Quart de Poblet << Quart de Poblet
# 78 Meliana << Meliana
# 79 Foios << Foios
# 80 Les Carolines - Fira << Benimàmet - València
# 81 Canyamelar << Cabanyal-Canyamelar - València
# 82 Font Almaguer << Benifaió
# 83 Sagunt << València
# 84 Campanar << Campanar - València
# 85 Massamagrell << Massamagrell
# 86 Massarrojos << Massarrojos
# 87 La Pobla de Farnals << La Pobla de Farnals
# 88 Facultats - Manuel Broseta << Exposició - València
# 89 El Clot << L'Eliana
# 90 Safranar << Patraix - València
# 91 Ll. Llarga - Terramelar << Paterna
# 92 Salt de l'Aigua << Manises
# 93 Bailén << La Roqueta - València
# 94 Rafelbunyol << Rafelbunyol
# 95 Alacant << Russafa - València
# 96 Faitanar << Quart de Poblet
# 97 L'Eliana << L'Eliana
# 98 Riba-roja de Túria << Riba-roja de Túria
# 99 Montesol << L'Eliana
# 100 Picassent << Picassent
# 101 Torrent << Torrent
# 102 Ciutat Arts i Ciències - Justícia << Ciutat de les Arts i les Ciències - València
# 103 Natzaret << Natzaret - València
# 104 La Granja << Burjassot
# 105 Sant Joan << Burjassot
# 106 Museros << Museros
# 107 Alboraia Palmaret << Alboraia
# 108 València la Vella << Riba-roja de Túria
# 109 València Sud << Faitanar - València
# 110 Beniferri << Benicalap - València
# 111 Pl. Espanya << La Roqueta - València
# 112 Benimodo << Benimodo
# 113 Ausiàs March << Carlet
# 114 Espioca << Picassent
# 115 Seminari - CEU << Moncada
# 116 Amado Granell - Montolivet << Montolivet - València
# 117 Tarongers - Ernest Lluch << La Carrasca - València
# 118 Mislata Almassil << Mislata
# 119 Cabanyal << Cabanyal - València
# 120 Nou d'Octubre << Soternes - València
# 121 Alameda << La Xerea - València
# 122 Manises << Manises
# 123 Paterna << Paterna
# 124 Marítim << Aiora - València
# 125 Benimàmet << Benimàmet - València
# 126 Cantereria << Burjassot
# 127 Benaguasil << Benaguasil
# 128 Realón << Picassent
# 129 Beteró << La Carrasca - València
# 130 Marxalenes << Marxalenes - València
# 131 Vicente Zaragozá << Ciutat Universitària - València
# 132 Trinitat << Benimaclet - València
# 133 La Pobla de Vallbona << La Pobla de Vallbona
# 134 Benimaclet << Benimaclet - València
# 135 La Canyada << Paterna
# 136 Santa Rita << Paterna
# 137 Massalavés << Massalavés
# 138 Empalme << Burjassot
# 139 La Cadena << Cabanyal-Canyamelar - València
# 140 Platja Malva-rosa << Cabanyal-Canyamelar - València
# 141 Platja les Arenes << Cabanyal-Canyamelar - València
# 0 Equador - Pintor Matarana << Benicalap - València
# 1 Les Corts << Benicalap - València
# 2 General Avilés - Dr. Nicasi Benlloch << Benicalap - València
# 3 Corts Valencianes - Palau de Congressos << Benicalap - València
# 658 el Tremolar - Crist del Refugi << Benimàmet - València
# 659 Na Jordana << Benimàmet - València
# 660 Dr. Soriano Benlloch - Rafael Tenes Escrich << Benimàmet - València
# 661 Garbí << Benimàmet - València
# 662 Jesús Morante Borràs  - << Benimàmet - València
# 663 Ribàs  - Ador << Benimàmet - València
# 664 Felipe Valls - Lluís Cano << Benimàmet - València
# 665 Orriols - Sant Miquel dels Reis << Benimàmet - València
# 666 Tomàs Montañana - França << La Llum - València
# 667 la Malva-rosa - Sant Joan de Deu << Beniferri - València
# 668 Dr. Tomàs Sala  - Sant Vicent Màrtir << Beniferri - València
# 669 Camp de Túria - Mestre Rodrigo << Beniferri - València
# 670 Tanatori Municipal << Beniferri - València
# 671 Embarcador de l'Albufera << El Palmar - València
# 672 Embarcador de l'Albufera << El Palmar - València
# 673 La Malva-rosa - Gran Canària << El Palmar - València
# 674 La Cadena - Pare Antón Martí << El Palmar - València
# 675 Sagunt - Pare Urbà << El Palmar - València
# 676 Pinars  - El Saler << El Saler - València
# 677 Gola de Puchol << El Saler - València
# 678 Gola de Puchol << El Saler - València
# 679 Gola de Puchol << El Saler - València
# 680 Gola de Puchol << El Saler - València
# 681 Pinars - Carretera del Palmar << El Saler - València
# 682 Campanar - Ricardo Micó << El Saler - València
# 683 Carretera del Palmar - Pinars << El Saler - València
# 684 Parc Gulliver << El Saler - València
# 685 Constitució - Xest << El Saler - València
# 686 Hospital General << El Saler - València
# 687 Tres Creus  - Pare Esteban Pernet << La Fontsanta - València
# 688 Mercat de Castilla << La Fontsanta - València
# 689 Mediterrània - Dr. Lluch << La Fontsanta - València
# 690 Mercat de Torrefiel << La Fontsanta - València
# 691 Aragó - Finlàndia << La Fontsanta - València
# 692 Pare Esteban Pernet - Misericòrdia << La Fontsanta - València
# 693 Eugènia Viñes - Mare de Déu del Sufragi << La Fontsanta - València
# 694 Tomàs Montañana  - Astúries << La Fontsanta - València
# 695 Cid - Hospital << La Fontsanta - València
# 696 La Bene << Sant Llorenç - València
# 697 Duc de Mandas - Motilla del Palancar << Sant Llorenç - València
# 698 Constitució - Duc de Mandas << Els Orriols - València
# 699 Conca - Mossén Fenollar << Els Orriols - València
# 700 Constitució  - Tavernes Blanques << Els Orriols - València
# 701 Constitució  - Tavernes Blanques << Els Orriols - València
# 702 Creu Coberta << Els Orriols - València
# 703 Gavines - Entrada Filero << El Perellonet - València
# 704 Gavines - Front Entrada Ventura << El Perellonet - València
# 705 Petxina - Racó d'Ademús << El Perellonet - València
# 706 Gavines - Botavara << El Perellonet - València
# 707 Tres Creus - Tres Forques << Vara de Quart - València
# 708 Escola Oficial d'Idiomes << Vara de Quart - València
# 709 Pius XII - Centre Comercial << Vara de Quart - València
# 710 Arxiduc Carles - Fontanars dels Alforins << Vara de Quart - València
# 711 Tres Forques - Casa Misericòrdia << Vara de Quart - València
# 712 Foc - Amadeu Desfilis << Ciutat Fallera - València
# 713 Blasco Ibáñez - Rectorat << Ciutat Fallera - València
# 714 Passeig Marítim - Vicent la Roda << La Malva-Rosa - València
# 28 L'Alcudia << L'Alcúdia
# 29 Loriguilla-Reva << Loriguilla
# 30 Montesa << Montesa
# 31 Nules-Villavieja << Nules
# 32 Platja i Grau de Gandia << Gandia
# 33 Puçol << Puçol
# 34 Requena << Requena
# 35 Roca-Cuper << Meliana
# 36 San Antonio de Requena << Requena
# 37 Siete Aguas << Setaigües
# 38 Silla << Silla
# 39 Sueca << Sueca
# 40 Tavernes de la Valldigna << Tavernes de la Valldigna
# 41 Utiel << Utiel
# 42 Valencia Sant Isidre << Sant Isidre - València
# 43 Valencia-Cabanyal << Cabanyal - València
# 44 Vila-Real << Vila-real
# 45 Algemesi << Algemesí
# 46 Algimia-Ciudad << Algímia d'Alfara
# 47 Alzira << Alzira
# 48 Benifaio << Benifaió
# 49 Burriana-Alquerias del Niño Perdido << Les Alqueries
# 50 Chiva << Xiva
# 51 Circuit Ricardo Tormo << Xest
# 52 La Pobla Llarga << La Pobla Llarga
# 53 L'Enova-Manuel << L'Énova
# 54 Massanassa << Massanassa
# 55 Moixent << Moixent
# 56 Moncofar << Moncofa
# 57 Navajas << Navajas
# 58 Sagunt << Sagunt
# 59 Segorbe-Ciudad << Segorbe
# 60 Sollana << Sollana
# 61 Soneja << Soneja
# 62 Vallada << Vallada
# 63 Venta Mina-Siete Aguas << Bunyol
# 64 Xativa << Xàtiva
# 65 Xirivella-L'Alter << Xirivella

# %%
gdf
# Out:
#         id                  nombre    linea                   geometry  \
# 0   237118          Mas del Rosari        4  POINT (-0.43582 39.52496)
# 1   237200                 La Cova        9  POINT (-0.48444 39.49889)
# 2   237215                Aeroport      3,5  POINT (-0.47492 39.49237)
# 3   237216               Almàssera        3  POINT (-0.35427 39.51226)
# 4   237142                   Colón  3,5,7,9  POINT (-0.37093 39.47015)
# ..     ...                     ...      ...                        ...
# 61   67217                  Soneja       C6  POINT (-0.43067 39.81202)
# 62   64004                 Vallada       C2  POINT (-0.68995 38.90899)
# 63   66205  Venta Mina-Siete Aguas       C3  POINT (-0.87066 39.45407)
# 64   64100                  Xativa           POINT (-0.52537 38.99183)
# 65   69200       Xirivella-L'Alter       C4  POINT (-0.42094 39.46395)
#
#       longitud     latitud           tipo                 municipio
# 0    -0.435825    39.52496  metrovalencia        La Coma - València
# 1    -0.484444    39.49889  metrovalencia                   Manises
# 2    -0.474919   39.492367  metrovalencia                   Manises
# 3    -0.354267   39.512257  metrovalencia                 Almàssera
# 4    -0.370928   39.470146  metrovalencia  Sant Francesc - València
# ..         ...         ...            ...                       ...
# 61  -0.4306676  39.8120247          renfe                    Soneja
# 62   -0.689953   38.908988          renfe                   Vallada
# 63   -0.870661   39.454073          renfe                    Bunyol
# 64  -0.5253742  38.9918333          renfe                    Xàtiva
# 65   -0.420941  39.4639487          renfe                 Xirivella
#
# [1329 rows x 8 columns]

# %% [markdown]
# ### Últimos retoques

# %%
# Traducimos las columnas para supabase

gdf.rename(columns={'nombre': 'name'}, inplace=True)
gdf.rename(columns={'latitud': 'latitude'}, inplace=True)
gdf.rename(columns={'longitud': 'longitude'}, inplace=True)
gdf.rename(columns={'linea': 'line'}, inplace=True)
gdf.rename(columns={'tipo': 'type'}, inplace=True)
gdf.rename(columns={'municipio': 'town'}, inplace=True)

gdf.head()
# Out:
#        id            name     line                   geometry longitude  \
# 0  237118  Mas del Rosari        4  POINT (-0.43582 39.52496) -0.435825
# 1  237200         La Cova        9  POINT (-0.48444 39.49889) -0.484444
# 2  237215        Aeroport      3,5  POINT (-0.47492 39.49237) -0.474919
# 3  237216       Almàssera        3  POINT (-0.35427 39.51226) -0.354267
# 4  237142           Colón  3,5,7,9  POINT (-0.37093 39.47015) -0.370928
#
#     latitude           type                      town
# 0   39.52496  metrovalencia        La Coma - València
# 1   39.49889  metrovalencia                   Manises
# 2  39.492367  metrovalencia                   Manises
# 3  39.512257  metrovalencia                 Almàssera
# 4  39.470146  metrovalencia  Sant Francesc - València

# %%
set(gdf.town)
# Out:
# {'Aiora - València',
#  'Albalat dels Sorells',
#  'Alberic',
#  'Alboraia',
#  'Albors - València',
#  'Albuixech',
#  'Aldaia',
#  'Algemesí',
#  'Alginet',
#  "Algímia d'Alfara",
#  'Almassora',
#  'Almenara',
#  'Almàssera',
#  'Alzira',
#  'Amistat - València',
#  'Arrancapins - València',
#  'Benaguasil',
#  'Benetússer',
#  'Benicalap - València',
#  'Benifaió',
#  'Benifaraig - València',
#  'Beniferri - València',
#  'Benimaclet - València',
#  'Benimodo',
#  'Benimàmet - València',
#  'Beteró - València',
#  'Borbotó - València',
#  'Bunyol',
#  'Burjassot',
#  'Bétera',
#  'Cabanyal - València',
#  'Cabanyal-Canyamelar - València',
#  'Campanar - València',
#  'Camí Fondo - València',
#  'Camí Real - València',
#  'Carcaixent',
#  'Carlet',
#  'Carpesa - València',
#  "Castellar-L'Oliveral - València",
#  'Castelló de la Plana',
#  'Castelló de la Ribera',
#  'Catarroja',
#  'Caudiel',
#  'Ciutat Fallera - València',
#  'Ciutat Jardí - València',
#  'Ciutat Universitària - València',
#  'Ciutat Vella - València',
#  'Ciutat de les Arts i les Ciències - València',
#  'Cullera',
#  'El Botànic - València',
#  'El Calvari - València',
#  'El Carme - València',
#  "El Forn d'Alcedo - València",
#  'El Grau - València',
#  'El Mercat - València',
#  'El Palmar - València',
#  'El Perellonet - València',
#  'El Pilar - València',
#  'El Pla del Remei - València',
#  'El Puig',
#  'El Saler - València',
#  'Els Orriols - València',
#  'En Corts - València',
#  'Estivella',
#  'Exposició - València',
#  'Faitanar - València',
#  'Favara - València',
#  'Foios',
#  'Gandia',
#  'Gilet',
#  'Godella',
#  'Grao - València',
#  'Jaume Roig - València',
#  "L'Alcúdia",
#  "L'Amistat - València",
#  "L'Eliana",
#  "L'Hort de Senabre - València",
#  "L'Illa Perduda - València",
#  "L'Énova",
#  'La Carrasca - València',
#  'La Coma - València',
#  'La Creu Coberta - València',
#  'La Creu del Grau - València',
#  'La Fonteta de Sant Lluís - València',
#  'La Fontsanta - València',
#  'La Gran Via - València',
#  'La Llosa',
#  'La Llum - València',
#  'La Malva-Rosa - València',
#  'La Petxina - València',
#  'La Pobla Llarga',
#  'La Pobla de Farnals',
#  'La Pobla de Vallbona',
#  'La Punta - València',
#  'La Raiosa - València',
#  'La Roqueta - València',
#  'La Seu - València',
#  'La Torre - València',
#  'La Vega Baixa - València',
#  'La Xerea - València',
#  'Les Alqueries',
#  'Les Cases de Barcena - València',
#  'Les Tendetes - València',
#  'Llíria',
#  'Loriguilla',
#  'Malilla - València',
#  'Manises',
#  'Marxalenes - València',
#  'Massalavés',
#  'Massalfassar',
#  'Massamagrell',
#  'Massanassa',
#  'Massarrojos',
#  'Meliana',
#  'Mestalla - València',
#  'Mislata',
#  'Moixent',
#  'Moncada',
#  'Moncofa',
#  'Montesa',
#  'Montolivet - València',
#  'Moreres - València',
#  'Morvedre - València',
#  'Museros',
#  'Na Rovella - València',
#  'Natzaret - València',
#  'Navajas',
#  'Nou Moles - València',
#  'Nules',
#  'Orriols - València',
#  'Paiporta',
#  'Paterna',
#  'Patraix - València',
#  'Penya-Roja - València',
#  'Picanya',
#  'Picassent',
#  'Pinedo - València',
#  'Poble Nou - València',
#  'Puçol',
#  'Quart de Poblet',
#  'Rafelbunyol',
#  'Requena',
#  'Riba-roja de Túria',
#  'Rocafort',
#  'Russafa - València',
#  'Safranar - València',
#  'Sagunt',
#  'Sant Antoni - València',
#  'Sant Francesc - València',
#  'Sant Isidre - València',
#  'Sant Llorenç - València',
#  'Sant Marcel·lí - València',
#  'Sant Pau - València',
#  'Segorbe',
#  'Setaigües',
#  'Silla',
#  'Sollana',
#  'Soneja',
#  'Soternes - València',
#  'Sueca',
#  'Tavernes de la Valldigna',
#  'Tormos - València',
#  'Torrefiel - València',
#  'Torrent',
#  'Tres Forques - València',
#  'Trinitat - València',
#  'Utiel',
#  'Vallada',
#  'València',
#  'Vara de Quart - València',
#  'Vila-real',
#  'Xeraco',
#  'Xest',
#  'Xilxes',
#  'Xirivella',
#  'Xiva',
#  'Xàtiva',
#  'Xèrica'}

# %% [markdown]
# ### Exportación

# %%
gdf.to_file('Datos transporte/transporte.geojson', driver='GeoJSON')  
gdf.to_csv("Datos transporte/transporte.csv", index=False)

# %% [markdown]
# <h1><center> Town </center></h1>

# %% [markdown]
# Atributos
# * id
# * name
# * created_at
# * province
# * latitude
# * longitude
# * address
# * reward

# %% [markdown]
# ### Obtener coordenadas

# %%
def similitud_2(x, y):
    """
    función que devuelve true en la similitud entre un municipio y una parada por nombre
    """
    
    a = x.find(" - València")
    if a!=-1:
        x = x[:a]
    
    s = SequenceMatcher(None, x, y).ratio()
    return s

# %%
municipios_coordenadas = {}
municipios_coordenadas_aux = {}

for town in gdf['town']:
    municipios_coordenadas[town] = None
    municipios_coordenadas_aux[town] = (0,None)    
    
    
for i, row in gdf.sort_values(by='town').iterrows():
    s = similitud_2(row['town'], row['name'])
    ss = municipios_coordenadas_aux[row.town][0]

    if s>ss:
        sss = (s, row['name'])
        municipios_coordenadas_aux[row.town] = sss
        municipios_coordenadas[row.town] = (row.latitude, row.longitude)

# %%
municipios_coordenadas_aux
# Out:
# {'La Coma - València': (0.38095238095238093, 'Mas del Rosari'),
#  'Manises': (1.0, 'Manises'),
#  'Almàssera': (1.0, 'Almàssera'),
#  'Sant Francesc - València': (0.3902439024390244,
#   'Centre de Salut Joan Llorens'),
#  'Aiora - València': (0.8, 'Ayora'),
#  'Bétera': (1.0, 'Bétera'),
#  'Torrent': (1.0, 'Torrent'),
#  'Alberic': (1.0, 'Alberic'),
#  'Carlet': (1.0, 'Carlet'),
#  'Moreres - València': (1.0, 'Moreres'),
#  'Sant Isidre - València': (1.0, 'Sant Isidre'),
#  'Els Orriols - València': (0.7777777777777778, 'Orriols'),
#  'Riba-roja de Túria': (1.0, 'Riba-roja de Túria'),
#  'La Raiosa - València': (0.36363636363636365, 'Uruguai - Misser Rabassa'),
#  'Patraix - València': (1.0, 'Patraix'),
#  'Picassent': (1.0, 'Picassent'),
#  'Paiporta': (1.0, 'Paiporta'),
#  'Burjassot': (1.0, 'Burjassot'),
#  'Godella': (1.0, 'Godella'),
#  'Sant Llorenç - València': (0.42105263157894735, 'La Bene'),
#  'Paterna': (1.0, 'Paterna'),
#  'Grao - València': (0.3, 'Grau - La Marina'),
#  'Torrefiel - València': (0.43902439024390244,
#   'Comte de Torrefiel - Riu Bidasoa'),
#  'València': (0.2857142857142857, 'Sagunt'),
#  'Llíria': (1.0, 'Llíria'),
#  'Arrancapins - València': (0.35714285714285715, 'Parc de Benicalap'),
#  'Picanya': (1.0, 'Picanya'),
#  'Albalat dels Sorells': (1.0, 'Albalat dels Sorells'),
#  'Marxalenes - València': (1.0, 'Marxalenes'),
#  'Benicalap - València': (1.0, 'Benicalap'),
#  'La Carrasca - València': (1.0, 'La Carrasca'),
#  'Cabanyal-Canyamelar - València': (0.6896551724137931, 'Canyamelar'),
#  'Alboraia': (0.64, 'Alboraia Palmaret'),
#  'Benaguasil': (1.0, 'Benaguasil'),
#  "L'Eliana": (1.0, "L'Eliana"),
#  "L'Alcúdia": (1.0, "L'Alcúdia"),
#  'Benimaclet - València': (1.0, 'Benimaclet'),
#  'Amistat - València': (1.0, 'Amistat'),
#  'Mestalla - València': (0.6153846153846154, 'Estadi de Mestalla'),
#  'Castelló de la Ribera': (0.5517241379310345, 'Castelló'),
#  'Alginet': (1.0, 'Alginet'),
#  'La Fonteta de Sant Lluís - València': (0.7407407407407407,
#   'Valencia-La Font de Sant Lluis'),
#  'Ciutat de les Arts i les Ciències - València': (0.6666666666666666,
#   'Ciutat Arts i Ciències - Justícia'),
#  'Mislata': (1.0, 'Mislata'),
#  'Campanar - València': (1.0, 'Campanar'),
#  'Rocafort': (1.0, 'Rocafort'),
#  'Moncada': (0.6086956521739131, 'Moncada - Alfara'),
#  'Russafa - València': (1.0, 'Russafa'),
#  'Morvedre - València': (0.2857142857142857, 'Almassora - Argenter Suàrez'),
#  'Orriols - València': (0.125, 'Estadi Ciutat de València'),
#  'Quart de Poblet': (1.0, 'Quart de Poblet'),
#  'Meliana': (1.0, 'Meliana'),
#  'Foios': (1.0, 'Foios'),
#  'Benimàmet - València': (1.0, 'Benimàmet'),
#  'Benifaió': (0.875, 'Benifaio'),
#  'Massamagrell': (1.0, 'Massamagrell'),
#  'Massarrojos': (1.0, 'Massarrojos'),
#  'La Pobla de Farnals': (1.0, 'La Pobla de Farnals'),
#  'Exposició - València': (0.21739130434782608,
#   'Joan Baptista Comes - Antonio Machado'),
#  'La Roqueta - València': (0.38095238095238093, 'Primat Reig'),
#  'Rafelbunyol': (1.0, 'Rafelbunyol'),
#  'Natzaret - València': (1.0, 'Natzaret'),
#  'Museros': (1.0, 'Museros'),
#  'Faitanar - València': (0.3, 'València Sud'),
#  'Benimodo': (1.0, 'Benimodo'),
#  'Montolivet - València': (0.5555555555555556, 'Amado Granell - Montolivet'),
#  'Cabanyal - València': (1.0, 'Cabanyal'),
#  'Soternes - València': (0.2857142857142857, "Nou d'Octubre"),
#  'La Xerea - València': (0.4, 'Alameda'),
#  'Ciutat Universitària - València': (0.5660377358490566,
#   'Primat Reig - Campus Universitari'),
#  'La Pobla de Vallbona': (1.0, 'La Pobla de Vallbona'),
#  'Massalavés': (1.0, 'Massalavés'),
#  'Tormos - València': (0.3, 'Pintor Sorolla'),
#  'Sant Antoni - València': (0.4827586206896552, 'Sagunt - Don Bosco'),
#  'El Calvari - València': (0.25, 'Campanar - Dr. Nicasi Benlloch'),
#  'Trinitat - València': (0.5, 'Florista'),
#  'Les Tendetes - València': (0.3125, 'Tres Creus - Bolívia'),
#  'Jaume Roig - València': (0.5882352941176471, 'Jaume Roig - Primat Reig'),
#  'El Carme - València': (0.2857142857142857, "Blanqueria - Pare d' Òrfens"),
#  'El Botànic - València': (0.3157894736842105, 'Espinosa - Ferran el Catòlic'),
#  'La Seu - València': (0.3333333333333333, 'Brasil - Velàzquez'),
#  'La Vega Baixa - València': (0.2564102564102564,
#   'Principal - Camí del Ribàs'),
#  'La Petxina - València': (0.56, 'Petxina - Terol'),
#  'El Mercat - València': (0.3076923076923077, 'Carda - Moro Zeit'),
#  'El Pilar - València': (0.3157894736842105, 'Encarnació - Guillem de Castro'),
#  'El Pla del Remei - València': (0.35294117647058826, 'Mercat de Campanar'),
#  'La Gran Via - València': (0.42857142857142855, 'Ciscar - Borriana'),
#  'Tres Forques - València': (0.6, 'Tres Forques - Josep Maestre'),
#  'Camí Fondo - València': (0.2564102564102564,
#   'Illes Canàries - Riu Escalona'),
#  'Penya-Roja - València': (0.32432432432432434, 'Menorca -  Centre Comercial'),
#  'La Creu del Grau - València': (0.38095238095238093,
#   'Illes Canàries - Trafalgar'),
#  'Safranar - València': (0.25806451612903225, 'Orxata - Mestre Serrano'),
#  'En Corts - València': (0.2553191489361702,
#   'Pare Esteban Pernet  - Centre Comercial'),
#  'Na Rovella - València': (0.4166666666666667, 'Sant Marcel·lí'),
#  'Malilla - València': (0.4666666666666667, 'Bulevard Sud  - Malilla'),
#  'Favara - València': (0.36363636363636365, 'Aiora'),
#  "L'Hort de Senabre - València": (0.3673469387755102,
#   'Camí nou de Picanya - Tres Creus'),
#  'La Creu Coberta - València': (0.3333333333333333, 'País Valencià - Colón'),
#  'Camí Real - València': (0.3157894736842105, 'La Barraca'),
#  'Sant Marcel·lí - València': (0.375, 'Dr. Lluch - Setmana Santa Marinera'),
#  "L'Amistat - València": (0.2962962962962963, 'Gavines - Bitàcora'),
#  'La Punta - València': (0.37037037037037035, 'Punta al Mar  - Riu'),
#  'El Grau - València': (0.2857142857142857, 'Camí de les Vaques  -'),
#  'Ciutat Jardí - València': (0.36363636363636365, 'Facultat de Filologia'),
#  'Nou Moles - València': (0.35294117647058826, 'Democràcia - Conselleries'),
#  'La Llum - València': (0.36363636363636365, 'Marconi - Barri de la Llum'),
#  'Beniferri - València': (0.2222222222222222, 'Tanatori Municipal'),
#  'El Palmar - València': (0.2962962962962963, 'Sagunt - Pare Urbà'),
#  'La Fontsanta - València': (0.4444444444444444, "Plaça d'Espanya"),
#  'El Perellonet - València': (0.4444444444444444, 'Real de Madrid - Hellín'),
#  'Vara de Quart - València': (0.41025641025641024,
#   'Fra Juníper Serra -Torrent'),
#  'Ciutat Fallera - València': (0.23255813953488372,
#   'Andreu Alfaro - Louis Braille'),
#  'La Malva-Rosa - València': (0.5945945945945946, 'la Malva-rosa - Riu Tajo'),
#  'Carpesa - València': (0.3076923076923077, 'Palmaret - Montcada'),
#  'Borbotó - València': (0.15384615384615385, 'Pinedo'),
#  'Poble Nou - València': (0.4864864864864865, 'Camí de Montcada - Poble Nou'),
#  'Les Cases de Barcena - València': (0.24390243902439024,
#   'Joan Verdeguer - Port'),
#  'Sant Pau - València': (0.38461538461538464, 'Drassanes del Grau'),
#  'Pinedo - València': (0.26666666666666666,
#   'Carrera del Riu - Trav. Pinedo a la Mar'),
#  "Castellar-L'Oliveral - València": (0.38095238095238093,
#   'el Tremolar - Guadiana'),
#  'La Torre - València': (0.24390243902439024,
#   "Real de Madrid - Carretera d'Alba"),
#  'Benifaraig - València': (0.4878048780487805,
#   'Benifaraig a Montcada - Boquera'),
#  'Beteró - València': (0.25, "Ciutat de l'Artista Faller"),
#  'Albors - València': (0.23076923076923078, 'Poliesportiu Malilla'),
#  'El Saler - València': (0.6153846153846154, 'Pinars  - El Saler'),
#  "El Forn d'Alcedo - València": (0.3, 'Karl Marx - Guadalquivir'),
#  "L'Illa Perduda - València": (0.2926829268292683,
#   'Sants Just i Pastor - Fusta'),
#  'Albuixech': (1.0, 'Albuixech'),
#  'Almassora': (1.0, 'Almassora'),
#  'Almenara': (1.0, 'Almenara'),
#  'Bunyol': (0.7272727272727273, 'Buñol'),
#  'Carcaixent': (1.0, 'Carcaixent'),
#  'Xilxes': (0.5714285714285714, 'Chilches'),
#  'Cullera': (1.0, 'Cullera'),
#  'Requena': (1.0, 'Requena'),
#  'Gilet': (1.0, 'Gilet'),
#  'La Llosa': (1.0, 'La Llosa'),
#  'Sagunt': (1.0, 'Sagunt'),
#  'Massalfassar': (1.0, 'Massalfassar'),
#  'Segorbe': (0.6666666666666666, 'Segorbe-Ciudad'),
#  'Ciutat Vella - València': (0.32432432432432434, 'Valencia-Estacio del Nord'),
#  'Xeraco': (1.0, 'Xeraco'),
#  'Xirivella': (0.6923076923076923, "Xirivella-L'Alter"),
#  'Aldaia': (1.0, 'Aldaia'),
#  'Benetússer': (0.6428571428571429, 'Alfafar-Benetusser'),
#  'Castelló de la Plana': (0.95, 'Castello de la Plana'),
#  'Catarroja': (1.0, 'Catarroja'),
#  'Caudiel': (1.0, 'Caudiel'),
#  'Xest': (0.6, 'Cheste'),
#  'El Puig': (1.0, 'El Puig'),
#  'Sollana': (1.0, 'Sollana'),
#  'Estivella': (0.43902439024390244, 'Estivella-Albalat dels Tarongers'),
#  'Gandia': (1.0, 'Gandia'),
#  'Xèrica': (0.4444444444444444, 'Jerica-Viver'),
#  'Loriguilla': (0.8, 'Loriguilla-Reva'),
#  'Montesa': (1.0, 'Montesa'),
#  'Nules': (0.47619047619047616, 'Nules-Villavieja'),
#  'Puçol': (1.0, 'Puçol'),
#  'Setaigües': (0.5, 'Siete Aguas'),
#  'Silla': (1.0, 'Silla'),
#  'Sueca': (1.0, 'Sueca'),
#  'Tavernes de la Valldigna': (1.0, 'Tavernes de la Valldigna'),
#  'Utiel': (1.0, 'Utiel'),
#  'Vila-real': (0.8888888888888888, 'Vila-Real'),
#  'Algemesí': (0.875, 'Algemesi'),
#  "Algímia d'Alfara": (0.5333333333333333, 'Algimia-Ciudad'),
#  'Alzira': (1.0, 'Alzira'),
#  'Les Alqueries': (0.3333333333333333, 'Burriana-Alquerias del Niño Perdido'),
#  'Xiva': (0.6666666666666666, 'Chiva'),
#  'La Pobla Llarga': (1.0, 'La Pobla Llarga'),
#  "L'Énova": (0.5714285714285714, "L'Enova-Manuel"),
#  'Massanassa': (1.0, 'Massanassa'),
#  'Moixent': (1.0, 'Moixent'),
#  'Moncofa': (0.9333333333333333, 'Moncofar'),
#  'Navajas': (1.0, 'Navajas'),
#  'Soneja': (1.0, 'Soneja'),
#  'Vallada': (1.0, 'Vallada'),
#  'Xàtiva': (0.8333333333333334, 'Xativa')}

# %%
# Las coordenadas corresponden a una estación de town

town = pd.DataFrame([[key, municipios_coordenadas[key][0], municipios_coordenadas[key][1] ] for key in sorted(municipios_coordenadas.keys())], columns=['name', 'latitude', 'longitude'])
town.head()
# Out:
#                    name   latitude longitude
# 0      Aiora - València  39.466427 -0.342969
# 1  Albalat dels Sorells  39.545265 -0.348289
# 2               Alberic   39.11705 -0.523526
# 3              Alboraia  39.495663 -0.355222
# 4     Albors - València  39.451848 -0.374466

# %% [markdown]
# ### Provincia

# %% [markdown]
# * https://ca.wikipedia.org/wiki/Llista_dels_municipis_del_Pa%C3%ADs_Valenci%C3%A0
#
# * https://ceice.gva.es/estatico/polin/WebHelp/Ajuda_SALT.htm#Toponimia/municipis_de_la_comunitat_valenciana.html
#
# * https://www.fvmp.es/guia-de-ayuntamientos-comunidad-valenciana/
#
# * https://datos.gob.es/es/catalogo/a10002983-capa-de-municipios-de-la-comunidad-valenciana

# %% [markdown]
# #### Exploración

# %%
municipios_ayt = "./Datos municipios/ayuntamiento_24.csv"
municipios_geojson = './Datos municipios/ca_municipios_20240405.geojson.json.geojson'
municipios_pdf = './Datos municipios/upv_muni.pdf'


# Trabajaremos con este, aunque los otros dos son interesantes y por eso los dejo ahí
m24_ayt = pd.read_csv(municipios_ayt)
m24_ayt.head()

# La forma de leer un pdf:


# pip install PyPDF2
# import PyPDF2

# with open(municipios_pdf, 'rb') as f:
#     reader = PyPDF2.PdfReader(f) 
#     text = ''
#     for page in reader.pages:
#         text += page.extract_text()
# print(text)
# Out:
#     INE ARTICULO_CAS NOMBRE_CAS ARTICULO_VAL NOMBRE_VAL   CENSO   TELÉFONO  \
# 0  3002          NaN      Agost          NaN      Agost    5067  965691043
# 1  3004          NaN     Aigües          NaN     Aigües    1146  965690061
# 2  3014          NaN   Alicante          NaN    Alacant  349282  965149110
# 3  3046          NaN      Busot          NaN      Busot    3534  965699092
# 4  3050          el    Campello          el    Campello   29993  965637200
#
#                                            EMAIL  \
# 0                            ajuntament@agost.es
# 1  secretaria@aigues.es;notificaciones@aigues.es
# 2                           alcaldia@alicante.es
# 3                                 busot@busot.es
# 4                        alcaldia@elcampello.org
#
#                        ALCALDE/SA    PARTIDO                WEB PROVINCIA  \
# 0       Juan Jose Castello Molina         PP       www.agost.es   Alacant
# 1        Emilio Jose Solbes Villo  PSPV-PSOE      www.aigues.es   Alacant
# 2             Luis Barcala Sierra         PP    www.alicante.es   Alacant
# 3        Alejandro Morant Climent         PP      www.busot.com   Alacant
# 4  Juan Jose Berenguer Alcobendas         PP  www.elcampello.es   Alacant
#
#       COMARCA                    DIRECCIÓN    CP
# 0  L'Alacantí           Plaça D'Espanya, 1  3698
# 1  L'Alacantí                     Mayor, 5  3569
# 2  L'Alacantí  Plaza Del Ayuntamiento, s/n  3002
# 3  L'Alacantí    Plaza del Ayuntamiento, 1  3111
# 4  L'Alacantí              Oncina Giner, 7  3560

# %%
# Resultado de concatenar por los nombres en valenciano
town2 = pd.merge(town, m24_ayt.rename(columns={'NOMBRE_VAL':'name'}), on=['name'], how='inner') # 69 filas
# Resultado de concatenar por los nombres en castellano
town3 = pd.merge(town, m24_ayt.rename(columns={'NOMBRE_CAS':'name'}), on=['name'], how='inner') # 66 filas

# %%
no_localizados = set(town['name']) - set(town2['name']) # - set(town3['name'])
no_localizados = [i for i in no_localizados if ' - València' not in i]
# len(no_localizados)
no_localizados
# Out:
# ['Xiva',
#  'La Llosa',
#  'El Puig',
#  'Massarrojos',
#  'La Pobla Llarga',
#  'Les Alqueries',
#  'La Pobla de Farnals',
#  "L'Énova",
#  'Xilxes',
#  'Xest',
#  'Castelló de la Ribera',
#  "L'Eliana",
#  'Xèrica',
#  'Alberic',
#  'Bunyol',
#  'La Pobla de Vallbona',
#  'Setaigües',
#  "L'Alcúdia"]

# %% [markdown]
# #### Arreglos

# %%
dic_adaptar_municipio = {'Villanueva de Viver':'Castelló de la Ribera', 'Chiva':'Xiva',
                         'Alcúdia': "L'Alcúdia", 'Jérica': 'Xèrica',
                         'Buñol': 'Bunyol', 'Llosa':'La Llosa', 'Puig de Santa Maria': 'El Puig',
                         'Cheste': 'Xest', 'Siete Aguas': 'Setaigües',
                         'Alqueries': 'Les Alqueries', 'Eliana': "L'Eliana",
                         'Énova': "L'Énova", 'Chilches':'Xilxes', 'alberic':'Alberic',
                         'Alcúdia de Crespins': "L'Alcúdia"
                           }

def adaptar_municipio(municipio):
    if municipio in dic_adaptar_municipio:
        return dic_adaptar_municipio[municipio]
    if 'La Pobla ' in municipio:
        return municipio
    elif 'Pobla ' in municipio:
        return 'La ' + municipio
    return municipio

m24_ayt.rename(columns={'NOMBRE_VAL':'name'}, inplace=True)
m24_ayt["name"] = list(map(adaptar_municipio,m24_ayt.name))

# %%
# Volvemos a probar
# Resultado de concatenar por los nombres en valenciano
town2 = pd.merge(town, m24_ayt, on=['name'], how='inner')
town2

no_localizados = set(town['name']) - set(town2['name']) # - set(town3['name'])
no_localizados = [i for i in no_localizados if ' - València' not in i]
# len(no_localizados)
no_localizados
# Out:
# ['Massarrojos']

# %%
# df = pd.DataFrame(columns=m24_ayt.columns)
massarrojos = {'name': 'Massarrojos', 'PROVINCIA': 'València', 'CP':'46112', 'DIRECCIÓN': 'Cura Bau, 10'}
m24_ayt.loc[len(m24_ayt)] = massarrojos
m24_ayt
# Out:
#          INE ARTICULO_CAS           NOMBRE_CAS ARTICULO_VAL  \
# 0     3002.0          NaN                Agost          NaN
# 1     3004.0          NaN               Aigües          NaN
# 2     3014.0          NaN             Alicante          NaN
# 3     3046.0          NaN                Busot          NaN
# 4     3050.0          el              Campello          el
# ..       ...          ...                  ...          ...
# 538  46142.0          NaN              Jalance          NaN
# 539  46144.0          NaN             Jarafuel          NaN
# 540  46239.0          NaN  Teresa de Cofrentes          NaN
# 541  46263.0          NaN                Zarra          NaN
# 542      NaN          NaN                  NaN          NaN
#
#                     name     CENSO     TELÉFONO  \
# 0                  Agost    5067.0  965691043.0
# 1                 Aigües    1146.0  965690061.0
# 2                Alacant  349282.0  965149110.0
# 3                  Busot    3534.0  965699092.0
# 4               Campello   29993.0  965637200.0
# ..                   ...       ...          ...
# 538              Jalance     810.0  962196011.0
# 539             Jarafuel     765.0  962198011.0
# 540  Teresa de Cofrentes     611.0  961893278.0
# 541                Zarra     364.0  961893015.0
# 542          Massarrojos       NaN          NaN
#
#                                              EMAIL  \
# 0                              ajuntament@agost.es
# 1    secretaria@aigues.es;notificaciones@aigues.es
# 2                             alcaldia@alicante.es
# 3                                   busot@busot.es
# 4                          alcaldia@elcampello.org
# ..                                             ...
# 538                        ayuntamiento@jalance.es
# 539                       ayuntamiento@jarafuel.es
# 540                secretaria@teresadecofrentes.es
# 541                           secretaria@zarra.org
# 542                                            NaN
#
#                          ALCALDE/SA    PARTIDO                       WEB  \
# 0         Juan Jose Castello Molina         PP              www.agost.es
# 1          Emilio Jose Solbes Villo  PSPV-PSOE             www.aigues.es
# 2               Luis Barcala Sierra         PP           www.alicante.es
# 3          Alejandro Morant Climent         PP             www.busot.com
# 4    Juan Jose Berenguer Alcobendas         PP         www.elcampello.es
# ..                              ...        ...                       ...
# 538     Jose Carlos Poveda Gabaldón         PP            www.jalance.es
# 539  Fernando Jorge Garcia Martínez         PP           www.jarafuel.es
# 540  José Javier Jiménez Miravalles         PP  www.teresadecofrentes.es
# 541                   Raul Martinez  PSPV-PSOE              www.zarra.es
# 542                             NaN        NaN                       NaN
#
#     PROVINCIA                      COMARCA                    DIRECCIÓN     CP
# 0     Alacant                   L'Alacantí           Plaça D'Espanya, 1   3698
# 1     Alacant                   L'Alacantí                     Mayor, 5   3569
# 2     Alacant                   L'Alacantí  Plaza Del Ayuntamiento, s/n   3002
# 3     Alacant                   L'Alacantí    Plaza del Ayuntamiento, 1   3111
# 4     Alacant                   L'Alacantí              Oncina Giner, 7   3560
# ..        ...                          ...                          ...    ...
# 538  València  El Valle de Cofrentes-Ayora       Plaza Ayuntamiento, 10  46624
# 539  València  El Valle de Cofrentes-Ayora                Glorieta, S/N  46623
# 540  València  El Valle de Cofrentes-Ayora             Plaza Iglesia, 1  46622
# 541  València  El Valle de Cofrentes-Ayora                    Panoja, 2  46621
# 542  València                          NaN                 Cura Bau, 10  46112
#
# [543 rows x 15 columns]

# %% [markdown]
# ##### Para València

# %%
# Tomamos la fila València
row_valencia = m24_ayt.loc[m24_ayt['name'] == 'València']
provincia = row_valencia.loc[500, 'PROVINCIA']
direccion = row_valencia.loc[500, 'DIRECCIÓN']
cp = row_valencia.loc[500, 'CP']

# %%
# Tomamos las filas que son de València
town_valencia = town[town['name'].str.contains('- València')]

# %%
# Arreglamos el df para que sean iguales
df = pd.concat([row_valencia, town_valencia])
df['PROVINCIA'] = df['PROVINCIA'].fillna(provincia)
df['DIRECCIÓN'] = df['DIRECCIÓN'].fillna(provincia)
df['CP'] = df['CP'].fillna(cp)

valencia = df[df['name']=='València'].index
df.drop(valencia, axis=0, inplace=True)
town_valencia = df

# %% [markdown]
# #### Fusión

# %%
town_final = pd.merge(town, m24_ayt, on=['name'], how='inner') # no usamos left por el tema que tomamos barrios
town_final = pd.concat([town_valencia, town_final])
town_final
# Out:
#         INE ARTICULO_CAS NOMBRE_CAS ARTICULO_VAL                    name  \
# 0       NaN          NaN        NaN          NaN        Aiora - València
# 4       NaN          NaN        NaN          NaN       Albors - València
# 14      NaN          NaN        NaN          NaN      Amistat - València
# 15      NaN          NaN        NaN          NaN  Arrancapins - València
# 18      NaN          NaN        NaN          NaN    Benicalap - València
# ..      ...          ...        ...          ...                     ...
# 83  12053.0          NaN     Xilxes          NaN                  Xilxes
# 84  46110.0          NaN  Xirivella          NaN               Xirivella
# 85  46111.0          NaN      Chiva          NaN                    Xiva
# 86  46145.0          NaN     Xàtiva          NaN                  Xàtiva
# 87  12071.0          NaN     Jérica          NaN                  Xèrica
#
#       CENSO     TELÉFONO                    EMAIL             ALCALDE/SA  \
# 0       NaN          NaN                      NaN                    NaN
# 4       NaN          NaN                      NaN                    NaN
# 14      NaN          NaN                      NaN                    NaN
# 15      NaN          NaN                      NaN                    NaN
# 18      NaN          NaN                      NaN                    NaN
# ..      ...          ...                      ...                    ...
# 83   2981.0  964590002.0     ajuntament@xilxes.es  Ismael Minguet Teresa
# 84  30749.0  963135050.0  ajuntament@xirivella.es  Paqui Bartual Bermell
# 85  16750.0  962520006.0    ayuntamiento@chiva.es    Amparo Fort Sanchez
# 86  30072.0  962289800.0       gabinete@xativa.es     Roger Cerdá Boluda
# 87   1794.0  964129177.0   ayuntamiento@jerica.es     Jorge Peiró Ripoll
#
#       PARTIDO               WEB PROVINCIA           COMARCA  \
# 0         NaN               NaN  València               NaN
# 4         NaN               NaN  València               NaN
# 14        NaN               NaN  València               NaN
# 15        NaN               NaN  València               NaN
# 18        NaN               NaN  València               NaN
# ..        ...               ...       ...               ...
# 83         PP         xilxes.es  Castelló    La Plana Baixa
# 84         PP  www.xirivella.es  València       L'Horta Sud
# 85         PP      www.chiva.es  València  La Hoya de Buñol
# 86  PSPV-PSOE     www.xativa.es  València        La Costera
# 87         PP     www.jerica.es  Castelló  El Alto Palancia
#
#                  DIRECCIÓN     CP    latitude   longitude
# 0                 València  46002   39.466427   -0.342969
# 4                 València  46002   39.451848   -0.374466
# 14                València  46002   39.470333   -0.350394
# 15                València  46002   39.495679   -0.396211
# 18                València  46002   39.490028   -0.390928
# ..                     ...    ...         ...         ...
# 83      Plaza de España, 5  12592  39.7812077  -0.1917555
# 84      Plaza Concordia, 6  46950  39.4639487   -0.420941
# 85  Plaza Gil Escarti, S/N  46370  39.4706442  -0.7232841
# 86  Alameda de Jaume I, 35  46800  38.9918333  -0.5253742
# 87    Historiador Vayo, 19  12450  39.9151971  -0.5693862
#
# [179 rows x 17 columns]

# %%
set(town_final['name']) - set(gdf['town'])
# Out:
# set()

# %%
# Añadir columnas
town_final['reward'] = None
town_final['uuid'] = None
town_final['created_at'] = None


# Quitar columnas
columnas_eliminar = ['INE', 'ARTICULO_CAS', 'NOMBRE_CAS', 'ARTICULO_VAL', 'CENSO', 'ALCALDE/SA', 'PARTIDO',]
columnas_que_eliminamos_pero_que_son_interesantes = ['TELÉFONO', 'EMAIL', 'WEB', 'COMARCA', 'CP']
town_final.drop(columnas_eliminar, axis=1, inplace=True)
town_final.drop(columnas_que_eliminamos_pero_que_son_interesantes, axis=1, inplace=True)

# Renombrar columnas
town_final.rename(columns={'PROVINCIA': 'province'}, inplace=True)
town_final.rename(columns={'DIRECCIÓN': 'address'}, inplace=True)

# Resetear el indice
town_final.reset_index(drop=True, inplace=True)


town_final.head()
# Out:
#                       name  province   address     CP   latitude longitude  \
# 0         Aiora - València  València  València  46002  39.466427 -0.342969
# 4        Albors - València  València  València  46002  39.451848 -0.374466
# 14      Amistat - València  València  València  46002  39.470333 -0.350394
# 15  Arrancapins - València  València  València  46002  39.495679 -0.396211
# 18    Benicalap - València  València  València  46002  39.490028 -0.390928
#
#    reward  uuid created_at
# 0    None  None       None
# 4    None  None       None
# 14   None  None       None
# 15   None  None       None
# 18   None  None       None

# %% [markdown]
# ### Exportar

# %%
town_final.to_csv("Datos municipios/municipio.csv", index=False)
